# %% [markdown]
# # 案例：手写数字

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
# %matplotlib inline 

digits = load_digits()
digits.images.shape
# Out:
# (1797, 8, 8)

# %% [markdown]
# ## 手写数字样本

# %%
import matplotlib.pyplot as plt

# 1.有bug造成无法运行的代码，显示"类型异常：TypeError: missing a required argument: 's'"
# fig, axes = plt.subplots(10, 10, figsize = (8, 8), 
#                          subplot_kw = {'xticks':[], 'yticks':[]}, 
#                          gridspec_kw=dict(hspace=0.1, wspace=0.1))

# for i, ax in enumerate(axes.flat):
#     ax.imshow(digits.images[i], cmap='binary', interpolation='nearest')
#     ax.text(0.05, str(digits.target[i]), 
#             transform=ax.transAxes, color='green')
 
# 2.重新敲了一遍的可以正常运行的代码   
# fig, axes = plt.subplots(10, 10, figsize = (8, 8), 
#                          subplot_kw = {'xticks':[], 'yticks':[]}, 
#                          gridspec_kw = dict(hspace = 0.1, wspace = 0.1))

# for i, ax in enumerate(axes.flat):
#     ax.imshow(digits.images[i], cmap = 'binary', interpolation = 'nearest')
#     ax.text(0.05, 0.05, str(digits.target[i]), 
#             transform = ax.transAxes, color = 'green')
    
# 3.书中源代码

# fig, axes = plt.subplots(10, 10, figsize=(8, 8),
#                          subplot_kw={'xticks':[], 'yticks':[]},
#                          gridspec_kw=dict(hspace=0.1, wspace=0.1))

# for i, ax in enumerate(axes.flat):
#     ax.imshow(digits.images[i], cmap='binary', interpolation='nearest')
#     ax.text(0.05, 0.05, str(digits.target[i]),
#             transform=ax.transAxes, color='green')

# 4.再次按源代码敲一遍的代码(可以完整运行)
fig, axes = plt.subplots(10, 10, figsize=(8, 8), 
                         subplot_kw={'xticks':[], 
                                     'yticks':[]}, 
                         
                         gridspec_kw=dict(hspace=0.1, 
                                          wspace=0.1))

for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], 
              cmap='binary', 
              interpolation='nearest')

    ax.text(0.5, 
            0.05, 
            str(digits.target[i]), 
            transform=ax.transAxes, 
            color='green')

plt.savefig(r"D:\Python-Excel\Data-analysis\Python-Data-Science\Objects\Matplotlib\images\digits.jpg")
