# %% [markdown]
# # 导入需要使用的画图工具

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('classic')
# %matplotlib inline

x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

# 一个简易的颜色条图例
plt.imshow(I)
plt.colorbar()
plt.savefig(r"D:\Python-Excel\Data-analysis\Python-Data-Science\Objects\Matplotlib\images\colorbar.jpg")

# %% [markdown]
# ## 配置颜色条

# %%
# 一个采用灰度配色方案的图形

plt.imshow(I, cmap='gray')
plt.savefig(r"D:\Python-Excel\Data-analysis\Python-Data-Science\Objects\Matplotlib\images\cmap.jpg")

# %% [markdown]
# ## 把jet转换为黑白的灰度图后看看具体的颜色

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.style.use('classic')
from matplotlib.colors import LinearSegmentedColormap
# %matplotlib inline

def grayscale_cmap(cmap):
    """为配色方案显示灰度图"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    # 将RGBA色转换为不同亮度的灰度值
    # 参考链接http://alienryderflex.com/hsp.html
    RGB_weight = [0.299, 0.587, 0.114]
    luminance = np.sqrt(np.dot(colors[:, :3] ** 2, 
                               RGB_weight)
                       )
    
    colors[:, :3] = luminance[:, np.newaxis]
    
    return LiearSegmentedColormap.from_list(cmap.name + "_gray", 
                                            colors, 
                                            cmap.N)


def view_colormap(cmap):
    """用等价的灰度图表示配色方案"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    cmap = grayscale_cmap(cmap)
    grayscale = cmap(np.arange(cmap.N))
    
    fig, ax = plt.subplots(2, 
                           figsize = (6, 2), 
                           subplot_kw = dict(xticks = [], 
                                             yticks = []))
    ax[0].imshow([colors], 
                 extent = [0, 10, 0, 1])
    
    ax[0].imshow([grayscale], 
                 extent = [0, 10, 0, 1])

# %%
view_colormap('jet')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-705126df87b8> in <module>
# ----> 1 view_colormap('jet')
#
# <ipython-input-22-7da075f96c61> in view_colormap(cmap)
#      25     colors = cmap(np.arange(cmap.N))
#      26
# ---> 27     cmap = grayscale_cmap(cmap)
#      28     grayscale = cmap(np.arange(cmap.N))
#      29
#
# <ipython-input-22-7da075f96c61> in grayscale_cmap(cmap)
#      17     colors[:, :3] = luminance[:, np.newaxis]
#      18
# ---> 19     return LiearSegmentedColormap.from_list(cmap.name + "_gray", colors, cmap.N)
#      20
#      21
#
# NameError: name 'LiearSegmentedColormap' is not defined
